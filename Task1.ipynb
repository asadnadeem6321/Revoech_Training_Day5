# %%
a = input("Enter your name")
print(type(a))
# Out:
# Enter your name asad
# <class 'str'>

# %%
a = input("Enter your age")
print(type(a))
a = int(a)
print(type(a))
# Out:
# Enter your age 123
# <class 'str'>
# <class 'int'>

# %%
a = input("Enter your current percentage status:")
print(type(a))
a = float(a)
print(type(a))
# Out:
# Enter your current percentage status: 12
# <class 'str'>
# <class 'float'>

# %%
a = int(input("Enter current month "))
print(type(a))
a = str(a)
print(type(a))
# Out:
# Enter current month  12
# <class 'int'>
# <class 'str'>

# %%
try:
    numerator = float(input("Enter first number "))
    denominator = float(input("Enter Second Numer: "))

    result = numerator/denominator

    print(result)
except:
    print("Error: Please enter any valid number.")
# Out:
# Enter first number  as
# Error: Please enter any valid number.

# %%
try:
    result= float(input("Enter first number "))
    result = 10 / result
    print(result)
except:
    print("You can't divide by zero!")
# Out:
# Enter first number  0
# You can't divide by zero!

# %%
try:
    result = 10 / 2
except ZeroDivisionError:
    print("You can't divide by zero!")
else:
    print("Division successful! Result:", result)
# Out:
# Division successful! Result: 5.0

# %%
try:
    result = 10 / 2
except ZeroDivisionError:
    print("You can't divide by zero!")
else:
    print("Division successful! Result:", result)
finally:
    print("This block always runs (e.g., closing files).")
# Out:
# Division successful! Result: 5.0
# This block always runs (e.g., closing files).
